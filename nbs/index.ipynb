# %% [markdown]
# # WellSpot Cosmos Client
#
# This project uses nbdev so the notebook in `nbs/00_client.ipynb` is the editable source for the importable module.
#
# Use `Cosmos_Wellspot_Client.ipynb` only for manual smoke tests against a real Azure environment.
